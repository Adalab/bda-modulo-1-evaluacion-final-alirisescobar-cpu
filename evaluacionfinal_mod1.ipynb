# %% [markdown]
# A lo largo de esta evaluación tendrás que crear una clase llamada TiendaOnline que cumpla los
# siguientes requisitos:
# La clase TiendaOnline debe tener los siguientes atributos:
# . inventario (lista de diccionarios): Un atributo para almacenar los productos en el inventario.
# Cada producto debe ser representado como un diccionario con las siguientes claves:
# 'nombre', 'precio', y 'cantidad'.

# %%
class TiendaOnline:
    def __init__(self, ventas_totales = 0.0):
        self.inventario = []
        self.ventas_totales = ventas_totales

    def agregar_producto(self, nombre, precio, cantidad):
        nuevo_producto = {"nombre": nombre, "precio": precio, "cantidad": cantidad}
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad #si el producto esta efectivamente, lo vamos a buscar por el nombre, no para que itere toda la list
            elif producto['nombre'] != nombre:
                print("¡Estoy agregando algo!")
                self.inventario.append(nuevo_producto)
                print(f"Producto {nombre} agregado con éxito.")
            else:
                print('error')  #defensivo por si acaso
                
la_tienda_friki = TiendaOnline()

# %%
class TiendaOnline:
    def __init__(self):
        self.inventario = []

    def agregar_producto(self, nombre, precio, cantidad):
        encontrado = False
for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad    
        nuevo_producto = {"nombre": nombre, "precio": precio, "cantidad": cantidad}
         #si el producto esta efectivamente, lo vamos a buscar por el nombre, no para que itere toda la list
            elif producto['nombre'] != nombre:
                print("¡Estoy agregando algo!")
                self.inventario.append(nuevo_producto)
                print(f"Producto {nombre} agregado con éxito.")
            else:
                print('error')  #defensivo por si acaso

# %% [markdown]
# Genero variables para los productos porque todavia no se muy bien mi estrategia

# %%
prodx = {'nombre' : 'x', 'precio': '0', 'cantidad': '0'}
prod1 = {'nombre' : 'Dnd 5', 'precio' : 45, 'cantidad': 5}
prod2 = {'nombre' : 'Daggerheart', 'precio': '55', 'cantidad': 8}
prod3 = {'nombre' : 'Shadowrun', 'precio': 15, 'cantidad': 2}
prod4 = {'nombre' : 'Fallout', 'precio': 50, 'cantidad': 20}
prod5 = {'nombre' : 'Star Wars', 'precio': 35, 'cantidad': 7}

# %%
inventario2= [prod1, prod2, prod3, prod4, prod5]

#print de prueba
print(inventario2)
#es un churro de texto dejame ponerlo mas bonito como en el ejemplo
for elemento in inventario2:
    print(elemento)
    #mejor verdad?
# Out:
# [{'nombre': 'Dnd 5', 'precio': 45, 'cantidad': 5}, {'nombre': 'Daggerheart', 'precio': '55', 'cantidad': 8}, {'nombre': 'Shadowrun', 'precio': 15, 'cantidad': 2}, {'nombre': 'Fallout', 'precio': 50, 'cantidad': 20}, {'nombre': 'Star Wars', 'precio': 35, 'cantidad': 7}]
# {'nombre': 'Dnd 5', 'precio': 45, 'cantidad': 5}
# {'nombre': 'Daggerheart', 'precio': '55', 'cantidad': 8}
# {'nombre': 'Shadowrun', 'precio': 15, 'cantidad': 2}
# {'nombre': 'Fallout', 'precio': 50, 'cantidad': 20}
# {'nombre': 'Star Wars', 'precio': 35, 'cantidad': 7}

# %% [markdown]
# La clase TiendaOnline debe tener los siguientes métodos:
# . agregar_producto(self, nombre, precio, cantidad): Este método agrega un producto al
# inventario o actualiza su cantidad si ya existe. Debe recibir el nombre, precio y cantidad del producto
# como parámetros.
# Itera a través del inventario y compara los nombres de los productos con el nombre
# proporcionado.
# Si el producto ya existe, actualiza la cantidad.
# Si no existe, agrega un nuevo producto al inventario

# %%
#print de prueba omaigo
la_tienda_friki.agregar_producto("Marvel", 45.0, 2)


#salio! ahora un print de prueba
print(la_tienda_friki.inventario)

#aca me quede un rato porque no entendia que tenia que llamar el print por el objeto y no por self fuera de la clase
# Out:
# []

# %%
print(la_tienda_friki.inventario)
# Out:
# []
