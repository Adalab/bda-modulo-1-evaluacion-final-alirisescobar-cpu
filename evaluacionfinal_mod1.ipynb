# %% [markdown]
# A lo largo de esta evaluación tendrás que crear una clase llamada TiendaOnline que cumpla los
# siguientes requisitos:
# La clase TiendaOnline debe tener los siguientes atributos:
# . inventario (lista de diccionarios): Un atributo para almacenar los productos en el inventario.
# Cada producto debe ser representado como un diccionario con las siguientes claves:
# 'nombre', 'precio', y 'cantidad'.

# %%
class TiendaOnline:
    def __init__(self,):
        self.inventario = []
        self.ventas_totales = 0.0

    def agregar_producto(self, nombre, precio, cantidad):
        encontrado = False 
#usar un flag fue la mejor manera que investigue para que no me diera error
        for producto in self.inventario:
            if producto['nombre'] == nombre:
                producto['cantidad'] += cantidad    
                encontrado = True
                print(f"🪄 Se han actualizado las cantidades del producto, Disponibles {cantidad} unidades nuevas de {nombre}")
                break
            
        if not encontrado:
            self.inventario.append({"nombre": nombre, "precio": precio, "cantidad": cantidad})
        else:
                print('error')  #defensivo por si acaso
    #defino el metodo para ver el inventario
    def ver_inventario(self):
         for producto in self.inventario:
              print("🎮", producto)

    #ahora el metodo para buscar producto
    def buscar_producto(self, nombre_buscar):
         print(f"⌛Procesando busqueda de {nombre_buscar}")
         for producto in self.inventario:
            if producto['nombre'].lower() in nombre_buscar.lower():
                    print("🪄Producto en existencia")
                    for key, value in producto.items(): #la pista que nos diste
                        print(f" ➡️ {key.capitalize()}, {value}")
                    return #importante para que no imprima todas las veces, este return me dio problemas
                    print(" 🧐 Producto no disponible, para agregar use el método de Agregar Producto")
#aqui habia un else pero lo tuve que quitar porque me imprimia no disponible por cada iteracion. 

    def actualizar_stock(self, nombre, cantidad):
        print(f"⌛Actualizando inventario de {nombre}") #mensajito para que sea mas amigable y de control
        actualizado = False  #copiamos lo mismo de arriba, el flag es diferente pero mismo metodo, en este caso fuera del bucle que me lie
        for producto in self.inventario:
            if producto['nombre'].lower() == nombre.lower(): #lower por si acaso me dejo una mayuscula
                producto['cantidad'] += cantidad    #importante
                actualizado = True
                print(f"Se han actualizado las cantidades del producto, Disponibles {producto['cantidad']} unidades de {nombre}")
                break #hago el print lUEGO de la suma que me costo verlo eh! y lo ve producto['cantidad'] tambien! el valor actualizado luego de la suma
        if not actualizado:
            print(" 🧐 Producto no disponible, para agregar use el método de Agregar Producto")
            
#ahora definimos eliminar productos
    def eliminar_producto(self, nombre):
        print(f"⌛Eliminando {nombre} del inventario") #mensajito para que sea mas amigable y de control
        eliminado = False 
        for producto in self.inventario:
                if producto['nombre'].lower() == nombre.lower() :
                    self.inventario.remove(producto)
                    eliminado = True #actualizo el flag antes del print
                    print(f"🪄Se ha eliminado {producto}, Allons-y!")
                    break

        if not eliminado: 
                    print(" 🧐 Producto no existe, nada que ver por aca!")
                         
    def calcular_valor_inventario(self):
        print(f"💰Calculando el valor total del inventario, verificando con el Gringotts Wizarding Bank...")
        print("-" * 40) # Una línea para separar todo
        total_inventario = 0
        for producto in self.inventario:
            valor_item = producto['cantidad'] * producto['precio'] #variables nueva para valor item y suma total
            total_inventario += valor_item #se va acumulando en total general con cada iteracion
            print(f"🪙 valor_{producto['nombre']} = {producto['cantidad']} * {producto['precio']} = {valor_item} galeones")
        print(f" El total general que hay en la Boveda de 'Mi tienda Friki' es de {total_inventario} galeones 💰")

# %%
#creo la tienda en una selda separada porque me da error al crear la lista
mi_tiendafriki = TiendaOnline()

# %% [markdown]
# La clase TiendaOnline debe tener los siguientes métodos:
# . agregar_producto(self, nombre, precio, cantidad): Este método agrega un producto al
# inventario o actualiza su cantidad si ya existe. Debe recibir el nombre, precio y cantidad del producto
# como parámetros.
# Itera a través del inventario y compara los nombres de los productos con el nombre
# proporcionado.
# Si el producto ya existe, actualiza la cantidad.
# Si no existe, agrega un nuevo producto al inventario

# %%
#finalmente funciono y almacena resultados
mi_tiendafriki.agregar_producto("DnD", 45.0, 8)
mi_tiendafriki.agregar_producto("Star Wars", 35.0, 15)
mi_tiendafriki.agregar_producto("Star trek", 15.0, 5)
mi_tiendafriki.agregar_producto("Legend of Zelda", 55.0, 12)

# %% [markdown]
# . ver_inventario(self): Muestra el inventario de productos con sus detalles.
# Utiliza un bucle for para recorrer el inventario.
# Imprime los detalles (nombre, precio, cantidad) de cada producto

# %%
mi_tiendafriki.ver_inventario()
#llamo a la funcion en otra celda, ejecuto todo y listo
# Out:
# 🎮 {'nombre': 'DnD', 'precio': 45.0, 'cantidad': 8}
# 🎮 {'nombre': 'Star Wars', 'precio': 35.0, 'cantidad': 15}
# 🎮 {'nombre': 'Star trek', 'precio': 15.0, 'cantidad': 5}
# 🎮 {'nombre': 'Legend of Zelda', 'precio': 55.0, 'cantidad': 12}

# %% [markdown]
# buscar_producto(self, nombre): Busca un producto en el inventario por nombre y muestra sus
# detalles si se encuentra. Debe recibir el nombre del producto como parámetro

# %%
mi_tiendafriki.buscar_producto("DnD")
# Out:
# ⌛Procesando busqueda de DnD
# 🪄Producto en existencia
#  ➡️ Nombre, DnD
#  ➡️ Precio, 45.0
#  ➡️ Cantidad, 8

# %%
mi_tiendafriki.buscar_producto("star wars")
# Out:
# ⌛Procesando busqueda de star wars
# 🪄Producto en existencia
#  ➡️ Nombre, Star Wars
#  ➡️ Precio, 35.0
#  ➡️ Cantidad, 15

# %% [markdown]
# actualizar_stock(self, nombre, cantidad): Actualiza el stock de un producto en el
# inventario. Debe recibir el nombre del producto y la cantidad a agregar o quitar como parámetros.

# %%
mi_tiendafriki.actualizar_stock("Star trek", 15)
mi_tiendafriki.actualizar_stock("Fallout", 20) #no esta, deberia dar no disponible
mi_tiendafriki.actualizar_stock("Star Wars", 35)
mi_tiendafriki.actualizar_stock("Barbie", 15) #no esta, deberia dar no disponible
# Out:
# ⌛Actualizando inventario de Star trek
# Se han actualizado las cantidades del producto, Disponibles 20 unidades de Star trek
# ⌛Actualizando inventario de Fallout
#  🧐 Producto no disponible, para agregar use el método de Agregar Producto
# ⌛Actualizando inventario de Star Wars
# Se han actualizado las cantidades del producto, Disponibles 50 unidades de Star Wars
# ⌛Actualizando inventario de Barbie
#  🧐 Producto no disponible, para agregar use el método de Agregar Producto

# %% [markdown]
# eliminar_producto(self, nombre):
# Elimina un producto del inventario por nombre. Debe
# recibir el nombre del producto como parámetro.

# %%
mi_tiendafriki.eliminar_producto("Star Wars")
# Out:
# ⌛Eliminando Star Wars del inventario
# 🪄Se ha eliminado {'nombre': 'Star Wars', 'precio': 35.0, 'cantidad': 50}, Allons-y!

# %%
mi_tiendafriki.ver_inventario()
#llamo al metodo para asegurarme que no esta!
# Out:
# 🎮 {'nombre': 'DnD', 'precio': 45.0, 'cantidad': 8}
# 🎮 {'nombre': 'Star trek', 'precio': 15.0, 'cantidad': 20}
# 🎮 {'nombre': 'Legend of Zelda', 'precio': 55.0, 'cantidad': 12}

# %%
#como me quedan solo 3 productos en el inventario, usaré mi método y agregaré mas
mi_tiendafriki.agregar_producto("Warhammer 40K", 60.0, 10)
mi_tiendafriki.agregar_producto("Magic The Gathering", 25.0, 30)
mi_tiendafriki.agregar_producto("Pokemon", 20.0, 25)
mi_tiendafriki.agregar_producto("Final Fantasy", 50.0, 7)
mi_tiendafriki.agregar_producto("World of Warcraft", 40.0, 9)
mi_tiendafriki.agregar_producto("Dark Souls", 45.0, 6)
mi_tiendafriki.agregar_producto("Elden Ring", 70.0, 11)
mi_tiendafriki.agregar_producto("Skyrim", 30.0, 14)
mi_tiendafriki.agregar_producto("Cyberpunk 2077", 65.0, 4)
mi_tiendafriki.agregar_producto("The Witcher", 50.0, 13)
mi_tiendafriki.agregar_producto("Super Mario", 35.0, 20)
mi_tiendafriki.agregar_producto("Sonic", 25.0, 18)
mi_tiendafriki.agregar_producto("Halo", 45.0, 16)
mi_tiendafriki.agregar_producto("Resident Evil", 40.0, 10)
mi_tiendafriki.agregar_producto("Silent Hill", 38.0, 5)
mi_tiendafriki.agregar_producto("Assassins Creed", 55.0, 8)
mi_tiendafriki.agregar_producto("God of War", 60.0, 12)
mi_tiendafriki.agregar_producto("Overwatch", 30.0, 17)
mi_tiendafriki.agregar_producto("League of Legends", 0.0, 100)
mi_tiendafriki.agregar_producto("Minecraft", 27.0, 22)

# %%
mi_tiendafriki.eliminar_producto("Barbie")
#probamos que pasa cuando el producto no existe
# Out:
# ⌛Eliminando Barbie del inventario
#  🧐 Producto no existe, nada que ver por aca!

# %% [markdown]
# calcular_valor_inventario(self): Calcula y muestra el valor total del inventario

# %%
mi_tiendafriki.calcular_valor_inventario()
# Out:
# 💰Calculando el valor total del inventario, verificando con el Gringotts Wizarding Bank...
# ----------------------------------------
# 🪙 valor_DnD = 8 * 45.0 = 360.0 galeones
# 🪙 valor_Star trek = 20 * 15.0 = 300.0 galeones
# 🪙 valor_Legend of Zelda = 12 * 55.0 = 660.0 galeones
# 🪙 valor_Warhammer 40K = 10 * 60.0 = 600.0 galeones
# 🪙 valor_Magic The Gathering = 30 * 25.0 = 750.0 galeones
# 🪙 valor_Pokemon = 25 * 20.0 = 500.0 galeones
# 🪙 valor_Final Fantasy = 7 * 50.0 = 350.0 galeones
# 🪙 valor_World of Warcraft = 9 * 40.0 = 360.0 galeones
# 🪙 valor_Dark Souls = 6 * 45.0 = 270.0 galeones
# 🪙 valor_Elden Ring = 11 * 70.0 = 770.0 galeones
# 🪙 valor_Skyrim = 14 * 30.0 = 420.0 galeones
# 🪙 valor_Cyberpunk 2077 = 4 * 65.0 = 260.0 galeones
# 🪙 valor_The Witcher = 13 * 50.0 = 650.0 galeones
# 🪙 valor_Super Mario = 20 * 35.0 = 700.0 galeones
# 🪙 valor_Sonic = 18 * 25.0 = 450.0 galeones
# 🪙 valor_Halo = 16 * 45.0 = 720.0 galeones
# 🪙 valor_Resident Evil = 10 * 40.0 = 400.0 galeones
# ...
